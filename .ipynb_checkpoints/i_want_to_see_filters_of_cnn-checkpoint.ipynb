# %%
import tensorflow_datasets as tfds
import tensorflow as tf
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import cv2

# %%
# (r_train, r_test), info = tfds.load(
#     'stanford_dogs',
#     split=['train','test'],
#     shuffle_files=True,
#     with_info=True
# )

# %%
INPUT_SHAPE = (224,224,3)

# %%
vgg16_model = tf.keras.applications.VGG16(include_top=False,
                                          input_shape=INPUT_SHAPE,
                                          weights='imagenet'
                                        )
vgg16_model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
def load_img(url):
    image = np.array(Image.open(url))
    tf_img = tf.convert_to_tensor(image[:,:,:3])
    rs_img = tf.image.resize(tf_img, INPUT_SHAPE[:2])
    rs_img = tf.expand_dims(rs_img, axis=0)
    return rs_img

# %%
def check_activation_map(model, layer_name, img):
    conv_layer = model.get_layer(layer_name)
    model = tf.keras.models.Model(model.input, conv_layer.output)
    outputs = model(img)
    op = outputs.numpy()[0]

    wt = np.mean(op, axis=(0,1))
    o = np.zeros((op.shape[:2]))
    for i, w in enumerate(wt):
        o += w * op[:,:,i]
    o /= np.max(o) # activation score를 normalize합니다.
    o = cv2.resize(o, (INPUT_SHAPE[0], INPUT_SHAPE[1])) # 원래 이미지의 크기로 resize합니다.
    return o

# %%
def check_filtered_grad_img(model, layer_name, img):
    conv_layer = model.get_layer(layer_name)
    model = tf.keras.models.Model(model.input, conv_layer.output)
    
    @tf.custom_gradient
    def guidedRelu(x):
        def grad(dy):
            return tf.cast(dy>0,"float32") * tf.cast(x>0, "float32") * dy
        return tf.nn.relu(x), grad
    
    layer_dict = [layer for layer in model.layers[1:] if hasattr(layer,'activation')]
    for layer in layer_dict:
        if layer.activation == tf.keras.activations.relu:
            layer.activation = guidedRelu

    with tf.GradientTape() as g:
        g.watch(img)
        out = model(img)
        grad = g.gradient(out, img)[0]

    return grad

# %%
def check_filters(model, layer_name, img):
    conv_layer = model.get_layer(layer_name)
    cw = conv_layer.get_weights()[0]
#     model = tf.keras.models.Model(model.input, conv_layer.output)
#     outputs = model(img)
#     op = outputs.numpy()[0]

#     wt = np.mean(op, axis=(0,1))
#     o = np.zeros((op.shape[:2]))
#     for i, w in enumerate(wt):
#         o += w * op[:,:,i]
#     o /= np.max(o) # activation score를 normalize합니다.
#     o = cv2.resize(o, (INPUT_SHAPE[0], INPUT_SHAPE[1])) # 원래 이미지의 크기로 resize합니다.
#     return o

# %%
plt.imshow(check_filters(vgg16_model, "block3_conv2", img))
# Out:
# (3, 3, 256, 256)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-c0edb2c44d7b> in <module>
# ----> 1 plt.imshow(check_filters(vgg16_model, "block3_conv2", img))
#
# ~\anaconda3\envs\venv\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, data, **kwargs)
#    2711         filternorm=filternorm, filterrad=filterrad, resample=resample,
#    2712         url=url, **({"data": data} if data is not None else {}),
# -> 2713         **kwargs)
#    2714     sci(__ret)
#    2715     return __ret
#
# ~\anaconda3\envs\venv\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1429     def inner(ax, *args, data=None, **kwargs):
#    1430         if data is None:
# -> 1431             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1432
#    1433         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\anaconda3\envs\venv\lib\site-packages\matplotlib\axes\_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, **kwargs)
#    5517                               resample=resample, **kwargs)
#    5518
# -> 5519         im.set_data(X)
#    5520         im.set_alpha(alpha)
#    5521         if im.get_clip_path() is None:
#
# ~\anaconda3\envs\venv\lib\site-packages\matplotlib\image.py in set_data(self, A)
#     696                 not np.can_cast(self._A.dtype, float, "same_kind")):
#     697             raise TypeError("Image data of dtype {} cannot be converted to "
# --> 698                             "float".format(self._A.dtype))
#     699
#     700         if self._A.ndim == 3 and self._A.shape[-1] == 1:
#
# TypeError: Image data of dtype object cannot be converted to float

# %%
img = load_img('./images/dog0.jpg')
plt.figure(figsize=(15,15))

plt.subplot(1,3,1)
plt.imshow(check_filtered_img(vgg16_model, "block1_conv1", img))

plt.subplot(1,3,2)
plt.imshow(check_filtered_img(vgg16_model, "block3_conv2", img))

plt.subplot(1,3,3)
plt.imshow(check_filtered_img(vgg16_model, "block5_conv3", img))

plt.show()

# %%
img = load_img('./images/dog0.jpg')
plt.figure(figsize=(15,15))

plt.subplot(1,3,1)
plt.imshow(check_filtered_grad_img(vgg16_model, "block1_conv1", img))

plt.subplot(1,3,2)
plt.imshow(check_filtered_grad_img(vgg16_model, "block3_conv2", img))

plt.subplot(1,3,3)
plt.imshow(check_filtered_grad_img(vgg16_model, "block5_conv3", img))

plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
